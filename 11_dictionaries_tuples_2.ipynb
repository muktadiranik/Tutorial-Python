# %%
a = {
    'a': 1, 
    'b': 2
}

# %%
print(a)
# Out:
# {'a': 1, 'b': 2}

# %%
a['a']
# Out:
# 1

# %%
a.clear()

# %%
a
# Out:
# {}

# %%
a = {
    'x': 1, 
    'y': 2, 
    'z': 3
}

# %%
'x' in a
# Out:
# True

# %%
1 in a
# Out:
# False

# %%
a = (1, 2)
